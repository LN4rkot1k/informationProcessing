# %%
import pandas as pd
import time
import matplotlib.pyplot as plt
from mlxtend.frequent_patterns import apriori, association_rules
from mlxtend.preprocessing import TransactionEncoder
import chardet

# %%
with open("baskets.csv", "rb") as f:
    result = chardet.detect(f.read())

df = pd.read_csv("baskets.csv", header=None, encoding=result["encoding"])
df
# Out:
#                     0                        1                        2   \
# 0             креветки                  миндаль                  авокадо
# 1            гамбургер              фрикадельки                     яйца
# 2                чатни                      NaN                      NaN
# 3              индейка                  авокадо                      NaN
# 4     минеральная вода                   молоко  энергетический батончик
# ...                ...                      ...                      ...
# 7496   сливочное масло  низкокалорийный майонез              свежий хлеб
# 7497         гамбургер       замороженные овощи                     яйца
# 7498            курица                      NaN                      NaN
# 7499           эскалоп              зеленый чай                      NaN
# 7500              яйца       замороженный смузи                   йогурт
#
#                           3                 4                    5      6   \
# 0              овощная смесь  зеленый виноград  цельнозерновая мука  батат
# 1                        NaN               NaN                  NaN    NaN
# 2                        NaN               NaN                  NaN    NaN
# 3                        NaN               NaN                  NaN    NaN
# 4                        рис       зеленый чай                  NaN    NaN
# ...                      ...               ...                  ...    ...
# 7496                     NaN               NaN                  NaN    NaN
# 7497           картофель-фри            журнал          зеленый чай    NaN
# 7498                     NaN               NaN                  NaN    NaN
# 7499                     NaN               NaN                  NaN    NaN
# 7500  низкокалорийный йогурт               NaN                  NaN    NaN
#
#           7                       8             9                       10  \
# 0     творог  энергетический напиток  томатный сок  низкокалорийный йогурт
# 1        NaN                     NaN           NaN                     NaN
# 2        NaN                     NaN           NaN                     NaN
# 3        NaN                     NaN           NaN                     NaN
# 4        NaN                     NaN           NaN                     NaN
# ...      ...                     ...           ...                     ...
# 7496     NaN                     NaN           NaN                     NaN
# 7497     NaN                     NaN           NaN                     NaN
# 7498     NaN                     NaN           NaN                     NaN
# 7499     NaN                     NaN           NaN                     NaN
# 7500     NaN                     NaN           NaN                     NaN
#
#                11   12     13                14      15           16  \
# 0     зеленый чай  мед  салат  минеральная вода  лосось  ягодный сок
# 1             NaN  NaN    NaN               NaN     NaN          NaN
# 2             NaN  NaN    NaN               NaN     NaN          NaN
# 3             NaN  NaN    NaN               NaN     NaN          NaN
# 4             NaN  NaN    NaN               NaN     NaN          NaN
# ...           ...  ...    ...               ...     ...          ...
# 7496          NaN  NaN    NaN               NaN     NaN          NaN
# 7497          NaN  NaN    NaN               NaN     NaN          NaN
# 7498          NaN  NaN    NaN               NaN     NaN          NaN
# 7499          NaN  NaN    NaN               NaN     NaN          NaN
# 7500          NaN  NaN    NaN               NaN     NaN          NaN
#
#                       17      18               19
# 0     замороженный смузи  шпинат  оливковое масло
# 1                    NaN     NaN              NaN
# 2                    NaN     NaN              NaN
# 3                    NaN     NaN              NaN
# 4                    NaN     NaN              NaN
# ...                  ...     ...              ...
# 7496                 NaN     NaN              NaN
# 7497                 NaN     NaN              NaN
# 7498                 NaN     NaN              NaN
# 7499                 NaN     NaN              NaN
# 7500                 NaN     NaN              NaN
#
# [7501 rows x 20 columns]

# %%
df = df.dropna(how="all", axis=0)
df = df.dropna(how="all", axis=1)

transactions = df.apply(lambda row: row.dropna().tolist(), axis=1).tolist()
print(len(transactions))
print(transactions[:5])
# Out:
# 7501
# [['креветки', 'миндаль', 'авокадо', 'овощная смесь', 'зеленый виноград', 'цельнозерновая мука', 'батат', 'творог', 'энергетический напиток', 'томатный сок', 'низкокалорийный йогурт', 'зеленый чай', 'мед', 'салат', 'минеральная вода', 'лосось', 'ягодный сок', 'замороженный смузи', 'шпинат', 'оливковое масло'], ['гамбургер', 'фрикадельки', 'яйца'], ['чатни'], ['индейка', 'авокадо'], ['минеральная вода', 'молоко', 'энергетический батончик', 'рис', 'зеленый чай']]

# %%
te = TransactionEncoder()
te_transformed = te.fit(transactions).transform(transactions)
df_transformed = pd.DataFrame(te_transformed, columns=te.columns_)
df_transformed
# Out:
#       авокадо  аксессуары  баклажаны  батат  батончик без глютена  бекон  \
# 0        True       False      False   True                 False  False
# 1       False       False      False  False                 False  False
# 2       False       False      False  False                 False  False
# 3        True       False      False  False                 False  False
# 4       False       False      False  False                 False  False
# ...       ...         ...        ...    ...                   ...    ...
# 7496    False       False      False  False                 False  False
# 7497    False       False      False  False                 False  False
# 7498    False       False      False  False                 False  False
# 7499    False       False      False  False                 False  False
# 7500    False       False      False  False                 False  False
#
#       белое вино  белый сыр  блинчики  ветчина  ...   чили  шампанское  \
# 0          False      False     False    False  ...  False       False
# 1          False      False     False    False  ...  False       False
# 2          False      False     False    False  ...  False       False
# 3          False      False     False    False  ...  False       False
# 4          False      False     False    False  ...  False       False
# ...          ...        ...       ...      ...  ...    ...         ...
# 7496       False      False     False    False  ...  False       False
# 7497       False      False     False    False  ...  False       False
# 7498       False      False     False    False  ...  False       False
# 7499       False      False     False    False  ...  False       False
# 7500       False      False     False    False  ...  False       False
#
#       шампунь  шоколад  шпинат  энергетический батончик  \
# 0       False    False    True                    False
# 1       False    False   False                    False
# 2       False    False   False                    False
# 3       False    False   False                    False
# 4       False    False   False                     True
# ...       ...      ...     ...                      ...
# 7496    False    False   False                    False
# 7497    False    False   False                    False
# 7498    False    False   False                    False
# 7499    False    False   False                    False
# 7500    False    False   False                    False
#
#       энергетический напиток  эскалоп  ягодный сок   яйца
# 0                       True    False         True  False
# 1                      False    False        False   True
# 2                      False    False        False  False
# 3                      False    False        False  False
# 4                      False    False        False  False
# ...                      ...      ...          ...    ...
# 7496                   False    False        False  False
# 7497                   False    False        False   True
# 7498                   False    False        False  False
# 7499                   False     True        False  False
# 7500                   False    False        False   True
#
# [7501 rows x 115 columns]

# %%
support_threshold = 0.002
confidence_thresholds = [0.7, 0.75, 0.8, 0.85, 0.9, 0.95]

support_itemsets_df = pd.DataFrame()
rules_df = pd.DataFrame()
execution_times = []
rules_count = []

for confidence_threshold in confidence_thresholds:
    print(f"\nПорог достоверности: {confidence_threshold}")

    start_time = time.time()

    frequent_itemsets = apriori(df_transformed, min_support=support_threshold, use_colnames=True)

    end_time = time.time()
    execution_times.append(end_time - start_time)
    
    frequent_itemsets["support_threshold"] = support_threshold
    frequent_itemsets["confidence_threshold"] = confidence_threshold
    frequent_itemsets["itemset_size"] = frequent_itemsets["itemsets"].apply(lambda x: len(x))

    frequent_itemsets = frequent_itemsets.sort_values(by=["itemset_size", "support"], ascending=[True, False])

    support_itemsets_df = pd.concat([support_itemsets_df, frequent_itemsets], ignore_index=True)

    rules = association_rules(frequent_itemsets, metric="confidence", min_threshold=confidence_threshold)
    rules_subset = rules[["antecedents", "consequents", "support", "confidence"]].copy()
    rules_subset["confidence_threshold"] = confidence_threshold

    rules_subset = rules_subset.sort_values(by=["support"], ascending=False)

    rules_df = pd.concat([rules_df, rules_subset], ignore_index=True)

    rules_count.append(len(rules_subset))

    print("\nЧастые наборы (support_itemsets_df)")
    display(frequent_itemsets)
    print("\nАссоциативные правила (rules_df)")
    display(rules_subset)
# Out:
# Порог достоверности: 0.7
#
# Частые наборы (support_itemsets_df)
#        support                                           itemsets  \
# 47    0.238368                                 (минеральная вода)
# 42    0.187975                                         (макароны)
# 110   0.179709                                             (яйца)
# 28    0.170911                                    (картофель-фри)
# 104   0.163845                                          (шоколад)
# ...        ...                                                ...
# 2476  0.002133           (яйца, минеральная вода, торт, макароны)
# 2480  0.002133                  (помидоры, рис, молоко, макароны)
# 2485  0.002133  (растительное масло, яйца, минеральная вода, м...
# 2487  0.002133             (торт, минеральная вода, яйца, молоко)
# 2491  0.002133            (яйца, минеральная вода, шоколад, торт)
#
#       support_threshold  confidence_threshold  itemset_size
# 47                0.002                   0.7             1
# 42                0.002                   0.7             1
# 110               0.002                   0.7             1
# 28                0.002                   0.7             1
# 104               0.002                   0.7             1
# ...                 ...                   ...           ...
# 2476              0.002                   0.7             4
# 2480              0.002                   0.7             4
# 2485              0.002                   0.7             4
# 2487              0.002                   0.7             4
# 2491              0.002                   0.7             4
#
# [2492 rows x 5 columns]
# Ассоциативные правила (rules_df)
#                                         antecedents         consequents  \
# 0                           (эскалоп, грибной соус)          (макароны)
# 4              (растительное масло, яйца, макароны)  (минеральная вода)
# 3                 (суп, замороженные овощи, молоко)  (минеральная вода)
# 5    (оливковое масло, замороженные овощи, шоколад)  (минеральная вода)
# 6                   (яйца, оливковое масло, молоко)  (минеральная вода)
# 7      (говяжий фарш, креветки, замороженные овощи)          (макароны)
# 1                   (макароны, обезжиренное молоко)  (минеральная вода)
# 9                         (блинчики, суп, макароны)  (минеральная вода)
# 8          (блинчики, растительное масло, макароны)  (минеральная вода)
# 2                           (красное вино, индейка)  (минеральная вода)
# 10                    (блинчики, говяжий фарш, рис)  (минеральная вода)
# 11  (оливковое масло, помидоры, замороженные овощи)          (макароны)
# 12                          (помидоры, рис, молоко)          (макароны)
#
#      support  confidence  confidence_threshold
# 0   0.004266    0.744186                   0.7
# 4   0.003066    0.718750                   0.7
# 3   0.003066    0.766667                   0.7
# 5   0.002800    0.700000                   0.7
# 6   0.002666    0.714286                   0.7
# 7   0.002533    0.791667                   0.7
# 1   0.002533    0.730769                   0.7
# 9   0.002266    0.772727                   0.7
# 8   0.002266    0.739130                   0.7
# 2   0.002133    0.727273                   0.7
# 10  0.002133    0.842105                   0.7
# 11  0.002133    0.842105                   0.7
# 12  0.002133    0.800000                   0.7
# Порог достоверности: 0.75
#
# Частые наборы (support_itemsets_df)
#        support                                           itemsets  \
# 47    0.238368                                 (минеральная вода)
# 42    0.187975                                         (макароны)
# 110   0.179709                                             (яйца)
# 28    0.170911                                    (картофель-фри)
# 104   0.163845                                          (шоколад)
# ...        ...                                                ...
# 2476  0.002133           (яйца, минеральная вода, торт, макароны)
# 2480  0.002133                  (помидоры, рис, молоко, макароны)
# 2485  0.002133  (растительное масло, яйца, минеральная вода, м...
# 2487  0.002133             (торт, минеральная вода, яйца, молоко)
# 2491  0.002133            (яйца, минеральная вода, шоколад, торт)
#
#       support_threshold  confidence_threshold  itemset_size
# 47                0.002                  0.75             1
# 42                0.002                  0.75             1
# 110               0.002                  0.75             1
# 28                0.002                  0.75             1
# 104               0.002                  0.75             1
# ...                 ...                   ...           ...
# 2476              0.002                  0.75             4
# 2480              0.002                  0.75             4
# 2485              0.002                  0.75             4
# 2487              0.002                  0.75             4
# 2491              0.002                  0.75             4
#
# [2492 rows x 5 columns]
# Ассоциативные правила (rules_df)
#                                        antecedents         consequents  \
# 0                (суп, замороженные овощи, молоко)  (минеральная вода)
# 1     (говяжий фарш, креветки, замороженные овощи)          (макароны)
# 2                        (блинчики, суп, макароны)  (минеральная вода)
# 3                    (блинчики, говяжий фарш, рис)  (минеральная вода)
# 4  (оливковое масло, помидоры, замороженные овощи)          (макароны)
# 5                          (помидоры, рис, молоко)          (макароны)
#
#     support  confidence  confidence_threshold
# 0  0.003066    0.766667                  0.75
# 1  0.002533    0.791667                  0.75
# 2  0.002266    0.772727                  0.75
# 3  0.002133    0.842105                  0.75
# 4  0.002133    0.842105                  0.75
# 5  0.002133    0.800000                  0.75
# Порог достоверности: 0.8
#
# Частые наборы (support_itemsets_df)
#        support                                           itemsets  \
# 47    0.238368                                 (минеральная вода)
# 42    0.187975                                         (макароны)
# 110   0.179709                                             (яйца)
# 28    0.170911                                    (картофель-фри)
# 104   0.163845                                          (шоколад)
# ...        ...                                                ...
# 2476  0.002133           (яйца, минеральная вода, торт, макароны)
# 2480  0.002133                  (помидоры, рис, молоко, макароны)
# 2485  0.002133  (растительное масло, яйца, минеральная вода, м...
# 2487  0.002133             (торт, минеральная вода, яйца, молоко)
# 2491  0.002133            (яйца, минеральная вода, шоколад, торт)
#
#       support_threshold  confidence_threshold  itemset_size
# 47                0.002                   0.8             1
# 42                0.002                   0.8             1
# 110               0.002                   0.8             1
# 28                0.002                   0.8             1
# 104               0.002                   0.8             1
# ...                 ...                   ...           ...
# 2476              0.002                   0.8             4
# 2480              0.002                   0.8             4
# 2485              0.002                   0.8             4
# 2487              0.002                   0.8             4
# 2491              0.002                   0.8             4
#
# [2492 rows x 5 columns]
# Ассоциативные правила (rules_df)
#                                        antecedents         consequents  \
# 0                    (блинчики, говяжий фарш, рис)  (минеральная вода)
# 1  (оливковое масло, помидоры, замороженные овощи)          (макароны)
#
#     support  confidence  confidence_threshold
# 0  0.002133    0.842105                   0.8
# 1  0.002133    0.842105                   0.8
# Порог достоверности: 0.85
#
# Частые наборы (support_itemsets_df)
# C:\Users\mazgu\AppData\Local\Temp\ipykernel_1896\430117286.py:33: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   rules_df = pd.concat([rules_df, rules_subset], ignore_index=True)
#        support                                           itemsets  \
# 47    0.238368                                 (минеральная вода)
# 42    0.187975                                         (макароны)
# 110   0.179709                                             (яйца)
# 28    0.170911                                    (картофель-фри)
# 104   0.163845                                          (шоколад)
# ...        ...                                                ...
# 2476  0.002133           (яйца, минеральная вода, торт, макароны)
# 2480  0.002133                  (помидоры, рис, молоко, макароны)
# 2485  0.002133  (растительное масло, яйца, минеральная вода, м...
# 2487  0.002133             (торт, минеральная вода, яйца, молоко)
# 2491  0.002133            (яйца, минеральная вода, шоколад, торт)
#
#       support_threshold  confidence_threshold  itemset_size
# 47                0.002                  0.85             1
# 42                0.002                  0.85             1
# 110               0.002                  0.85             1
# 28                0.002                  0.85             1
# 104               0.002                  0.85             1
# ...                 ...                   ...           ...
# 2476              0.002                  0.85             4
# 2480              0.002                  0.85             4
# 2485              0.002                  0.85             4
# 2487              0.002                  0.85             4
# 2491              0.002                  0.85             4
#
# [2492 rows x 5 columns]
# Ассоциативные правила (rules_df)
# Empty DataFrame
# Columns: [antecedents, consequents, support, confidence, confidence_threshold]
# Index: []
# Порог достоверности: 0.9
#
# Частые наборы (support_itemsets_df)
# C:\Users\mazgu\AppData\Local\Temp\ipykernel_1896\430117286.py:33: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   rules_df = pd.concat([rules_df, rules_subset], ignore_index=True)
#        support                                           itemsets  \
# 47    0.238368                                 (минеральная вода)
# 42    0.187975                                         (макароны)
# 110   0.179709                                             (яйца)
# 28    0.170911                                    (картофель-фри)
# 104   0.163845                                          (шоколад)
# ...        ...                                                ...
# 2476  0.002133           (яйца, минеральная вода, торт, макароны)
# 2480  0.002133                  (помидоры, рис, молоко, макароны)
# 2485  0.002133  (растительное масло, яйца, минеральная вода, м...
# 2487  0.002133             (торт, минеральная вода, яйца, молоко)
# 2491  0.002133            (яйца, минеральная вода, шоколад, торт)
#
#       support_threshold  confidence_threshold  itemset_size
# 47                0.002                   0.9             1
# 42                0.002                   0.9             1
# 110               0.002                   0.9             1
# 28                0.002                   0.9             1
# 104               0.002                   0.9             1
# ...                 ...                   ...           ...
# 2476              0.002                   0.9             4
# 2480              0.002                   0.9             4
# 2485              0.002                   0.9             4
# 2487              0.002                   0.9             4
# 2491              0.002                   0.9             4
#
# [2492 rows x 5 columns]
# Ассоциативные правила (rules_df)
# Empty DataFrame
# Columns: [antecedents, consequents, support, confidence, confidence_threshold]
# Index: []
# Порог достоверности: 0.95
#
# Частые наборы (support_itemsets_df)
# C:\Users\mazgu\AppData\Local\Temp\ipykernel_1896\430117286.py:33: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   rules_df = pd.concat([rules_df, rules_subset], ignore_index=True)
#        support                                           itemsets  \
# 47    0.238368                                 (минеральная вода)
# 42    0.187975                                         (макароны)
# 110   0.179709                                             (яйца)
# 28    0.170911                                    (картофель-фри)
# 104   0.163845                                          (шоколад)
# ...        ...                                                ...
# 2476  0.002133           (яйца, минеральная вода, торт, макароны)
# 2480  0.002133                  (помидоры, рис, молоко, макароны)
# 2485  0.002133  (растительное масло, яйца, минеральная вода, м...
# 2487  0.002133             (торт, минеральная вода, яйца, молоко)
# 2491  0.002133            (яйца, минеральная вода, шоколад, торт)
#
#       support_threshold  confidence_threshold  itemset_size
# 47                0.002                  0.95             1
# 42                0.002                  0.95             1
# 110               0.002                  0.95             1
# 28                0.002                  0.95             1
# 104               0.002                  0.95             1
# ...                 ...                   ...           ...
# 2476              0.002                  0.95             4
# 2480              0.002                  0.95             4
# 2485              0.002                  0.95             4
# 2487              0.002                  0.95             4
# 2491              0.002                  0.95             4
#
# [2492 rows x 5 columns]
# Ассоциативные правила (rules_df)
# Empty DataFrame
# Columns: [antecedents, consequents, support, confidence, confidence_threshold]
# Index: []

# %%
plt.figure(figsize=(12, 5))
plt.subplot(1, 2, 1)
plt.plot(confidence_thresholds, execution_times, marker="o", linestyle="-", color="b")
plt.title("Сравнение быстродействия при изменяемом пороге достоверности")
plt.xlabel("Порог достоверности")
plt.ylabel("Время выполнения (сек.)")
plt.grid(True)

plt.subplot(1, 2, 2)
plt.plot(confidence_thresholds, rules_count, marker="o", linestyle="-", color="r")
plt.title("Общее количество найденных правил")
plt.xlabel("Порог достоверности")
plt.ylabel("Количество правил")
plt.grid(True)

plt.tight_layout()
plt.show()

# %% [raw]
# На основе первого графика можно сделать вывод о том, что чем выше порог достоверности, тем быстрее работает алгоритм. При низких значениях порога алгоритм обрабатывает больше возможных правил, что замедляет его выполнение. При увеличении порога достоверности количество правил сокращается, соответственно, вычисления происходят быстрее.
#
# На основе второго графика можно сделать вывод о том, что при низком пороге достоверности количество найденных правил максимальное. По мере увеличения порога достоверности количество правил уменьшается, потому что более строгие требования к достоверности исключают многие правила, которые не достигают заданного уровня достоверности.

# %% [raw]
# Список правил, в которых антецедент и консеквент суммарно включают не более 7 правил.

# %%
filtered_rules = rules_df[rules_df.apply(lambda x: len(x["antecedents"]) + len(x["consequents"]) <= 7, axis=1)]

filtered_rules = filtered_rules[["antecedents", "consequents", "support", "confidence"]]

filtered_rules = filtered_rules.sort_values(by=["support"], ascending=False)

print("\nСписок правил с антецедентом и консеквентом <= 7 объектов:")
display(filtered_rules)
# Out:
# Список правил с антецедентом и консеквентом <= 7 объектов:
#                                         antecedents         consequents  \
# 0                           (эскалоп, грибной соус)          (макароны)
# 1              (растительное масло, яйца, макароны)  (минеральная вода)
# 2                 (суп, замороженные овощи, молоко)  (минеральная вода)
# 13                (суп, замороженные овощи, молоко)  (минеральная вода)
# 3    (оливковое масло, замороженные овощи, шоколад)  (минеральная вода)
# 4                   (яйца, оливковое масло, молоко)  (минеральная вода)
# 5      (говяжий фарш, креветки, замороженные овощи)          (макароны)
# 14     (говяжий фарш, креветки, замороженные овощи)          (макароны)
# 6                   (макароны, обезжиренное молоко)  (минеральная вода)
# 7                         (блинчики, суп, макароны)  (минеральная вода)
# 15                        (блинчики, суп, макароны)  (минеральная вода)
# 8          (блинчики, растительное масло, макароны)  (минеральная вода)
# 9                           (красное вино, индейка)  (минеральная вода)
# 12                          (помидоры, рис, молоко)          (макароны)
# 11  (оливковое масло, помидоры, замороженные овощи)          (макароны)
# 10                    (блинчики, говяжий фарш, рис)  (минеральная вода)
# 16                    (блинчики, говяжий фарш, рис)  (минеральная вода)
# 17  (оливковое масло, помидоры, замороженные овощи)          (макароны)
# 18                          (помидоры, рис, молоко)          (макароны)
# 19                    (блинчики, говяжий фарш, рис)  (минеральная вода)
# 20  (оливковое масло, помидоры, замороженные овощи)          (макароны)
#
#      support  confidence
# 0   0.004266    0.744186
# 1   0.003066    0.718750
# 2   0.003066    0.766667
# 13  0.003066    0.766667
# 3   0.002800    0.700000
# 4   0.002666    0.714286
# 5   0.002533    0.791667
# 14  0.002533    0.791667
# 6   0.002533    0.730769
# 7   0.002266    0.772727
# 15  0.002266    0.772727
# 8   0.002266    0.739130
# 9   0.002133    0.727273
# 12  0.002133    0.800000
# 11  0.002133    0.842105
# 10  0.002133    0.842105
# 16  0.002133    0.842105
# 17  0.002133    0.842105
# 18  0.002133    0.800000
# 19  0.002133    0.842105
# 20  0.002133    0.842105

# %% [raw]
# Глядя на датасет можно сделать вывод о том, что чаще всего встречаются правила с консеквентом минеральная вода или макароны. Это означает, что эти продукты часто берут в сочетании с другими продуктами. Глядя на достоверность, самыми нажедными правилами являются правила с достоверностью 84%:...
# Самым распространенным правилом является эскалоп,грибной соус -> макароны. Это правило имеет наибольшую поддержку.
